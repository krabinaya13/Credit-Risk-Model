# %%
import numpy as np
import pandas as pd

print(np.__version__)  # Check NumPy version
print(pd.__version__)  # Check Pandas version

loan_data_inputs_train = pd.read_csv('C:\\Users\\lenovo\\Downloads\\loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('C:\\Users\\lenovo\\Downloads\\loan_data_targets_train.csv', index_col = 0 ,header = None)
loan_data_inputs_test = pd.read_csv('C:\\Users\\lenovo\\Downloads\\loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('C:\\Users\\lenovo\\Downloads\\loan_data_targets_test.csv', index_col = 0, header = None)

loan_data_inputs_train.head()

print(loan_data_inputs_train.columns.tolist())
# Out:
# 2.2.3
# 2.2.3
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_820\2888113183.py:8: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan_data_targets_train = pd.read_csv('C:\\Users\\lenovo\\Downloads\\loan_data_targets_train.csv', index_col = 0 ,header = None)
# ...

# %%
loan_data_targets_train.head()
# Out:
#           1
# 0
# 0  good_bad
# 0         1
# 1         0
# 2         1
# 3         1

# %%
loan_data_targets_train = loan_data_targets_train.dropna()
loan_data_targets_train.head()
# Out:
#           1
# 0
# 0  good_bad
# 0         1
# 1         0
# 2         1
# 3         1

# %%
print(loan_data_targets_train.head())

# Check the index
print("Index:", loan_data_targets_train.index)

# Check the number of rows and columns
print("Shape:", loan_data_targets_train.shape)
# Out:
#           1
# 0
# 0  good_bad
# 0         1
# 1         0
# 2         1
# 3         1
# Index: Index([     0,      0,      1,      2,      3,      4,      5,      7,      8,
#             9,
#        ...
#        466269, 466270, 466271, 466273, 466275, 466276, 466277, 466278, 466279,
#        466283],
#       dtype='int64', name=0, length=373029)
# Shape: (373029, 1)

# %%
loan_data_targets_train = loan_data_targets_train.reset_index(drop=True)

# %%
# Drop the first row (index 0)
if 0 in loan_data_targets_train.index:
    loan_data_targets_train = loan_data_targets_train.drop(0)
else:
    print("Row with index 0 does not exist. Skipping drop.")

# Rename the column to 'good_bad'
loan_data_targets_train.columns = ['good_bad']

# Reset the index
loan_data_targets_train = loan_data_targets_train.reset_index(drop=True)

# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(loan_data_targets_train)
# Out:
# Cleaned DataFrame:
#        good_bad
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# ...         ...
# 373023        0
# 373024        0
# 373025        1
# 373026        1
# 373027        1
#
# [373028 rows x 1 columns]

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 327)

# %%
loan_data_inputs_test.shape
# Out:
# (373028, 327)

# %%
loan_data_targets_test.shape
# Out:
# (93258, 1)

# %%
# Here we select a limited set of input variables in a new dataframe.
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , [ 'Grade : A', 'Grade : B', 'Grade : C', 'Grade : D', 'Grade : E', 'Grade : F', 'Grade : G', 'sub_grade : A1', 'sub_grade : A2', 'sub_grade : A3', 'sub_grade : A4', 'sub_grade : A5', 'sub_grade : B1', 'sub_grade : B2', 'sub_grade : B3', 'sub_grade : B4', 'sub_grade : B5', 'sub_grade : C1', 'sub_grade : C2', 'sub_grade : C3', 'sub_grade : C4', 'sub_grade : C5', 'sub_grade : D1', 'sub_grade : D2', 'sub_grade : D3', 'sub_grade : D4', 'sub_grade : D5', 'sub_grade : E1', 'sub_grade : E2', 'sub_grade : E3', 'sub_grade : E4', 'sub_grade : E5', 'sub_grade : F1', 'sub_grade : F2', 'sub_grade : F3', 'sub_grade : F4', 'sub_grade : F5', 'sub_grade : G1', 'sub_grade : G2', 'sub_grade : G3', 'sub_grade : G4', 'sub_grade : G5', 'home_ownership : ANY', 'home_ownership : MORTGAGE', 'home_ownership : NONE', 'home_ownership : OTHER', 'home_ownership : OWN', 'home_ownership : RENT', 'verification_status : Not Verified', 'verification_status : Source Verified', 'verification_status : Verified', 'loan_status : Charged Off', 'loan_status : Current', 'loan_status : Default', 'loan_status : Does not meet the credit policy. Status:Charged Off', 'loan_status : Does not meet the credit policy. Status:Fully Paid', 'loan_status : Fully Paid', 'loan_status : In Grace Period', 'loan_status : Late (16-30 days)', 'loan_status : Late (31-120 days)', 'purpose : car', 'purpose : credit_card', 'purpose : debt_consolidation', 'purpose : educational', 'purpose : home_improvement', 'purpose : house', 'purpose : major_purchase', 'purpose : medical', 'purpose : moving', 'purpose : other', 'purpose : renewable_energy', 'purpose : small_business', 'purpose : vacation', 'purpose : wedding', 'addr_state : AK', 'addr_state : AL', 'addr_state : AR', 'addr_state : AZ', 'addr_state : CA', 'addr_state : CO', 'addr_state : CT', 'addr_state : DC', 'addr_state : DE', 'addr_state : FL', 'addr_state : GA', 'addr_state : HI', 'addr_state : IA', 'addr_state : ID', 'addr_state : IL', 'addr_state : IN', 'addr_state : KS', 'addr_state : KY', 'addr_state : LA', 'addr_state : MA', 'addr_state : MD', 'addr_state : ME', 'addr_state : MI', 'addr_state : MN', 'addr_state : MO', 'addr_state : MS', 'addr_state : MT', 'addr_state : NC', 'addr_state : NE', 'addr_state : NH', 'addr_state : NJ', 'addr_state : NM', 'addr_state : NV', 'addr_state : NY', 'addr_state : OH', 'addr_state : OK', 'addr_state : OR', 'addr_state : PA', 'addr_state : RI', 'addr_state : SC', 'addr_state : SD', 'addr_state : TN', 'addr_state : TX', 'addr_state : UT', 'addr_state : VA', 'addr_state : VT', 'addr_state : WA', 'addr_state : WI', 'addr_state : WV', 'addr_state : WY', 'initial_list_status : f', 'initial_list_status : w', 'home_ownership : RENT_OTHER_NONE_ANY', 'addr_state : ND', 'addr_state : ND_NE_IA_NV_FL_HI_AL', 'addr_state : NM_VA', 'addr_state : OK_TN_MO_LA_MD_NC', 'addr_state : UT_KY_AZ_NJ', 'addr_state : AR_MI_PA_OH_MN', 'addr_state : RI_MA_DE_SD_IN', 'addr_state : GA_WA_OR', 'addr_state : WI_MT', 'addr_state : IL_CT', 'addr_state : KS_SC_CO_VT_AK_MS', 'addr_state : WV_NH_WY_DC_ME_ID', 'purpose : SB_ED', 'purpose : HO_OT_RE_ME', 'purpose : WE_VA_DC', 'purpose : HI_MP_CA_CC', 'term : 36', 'term : 60', 'emp_length : 0', 'emp_length : 1', 'emp_length : 2-4', 'emp_length : 5-6', 'emp_length : 7-9', 'emp_length : 10', 'mths_since_issue_d_date_factor', 'mths_since_issue_d_date_factor : <38', 'mths_since_issue_d_date_factor : 38-39', 'mths_since_issue_d_date_factor : 40-41', 'mths_since_issue_d_date_factor : 42-48', 'mths_since_issue_d_date_factor : 49-52', 'mths_since_issue_d_date_factor : 53-64', 'mths_since_issue_d_date_factor : 65-84', 'mths_since_issue_d_date_factor : >84', 'int_rate_factor', 'int_rate : <9.548', 'int_rate : 9.548-12.025', 'int_rate : 12.025-15.74', 'int_rate : 15.74-20.281', 'int_rate : >20.281', 'funded_amnt_factor', 'mths_since_earliest_cr_line_factor', 'mths_since_earliest_cr_line_factor : <70', 'mths_since_earliest_cr_line_factor : 70-93', 'mths_since_earliest_cr_line_factor : 94-140', 'mths_since_earliest_cr_line_factor : 141-270', 'mths_since_earliest_cr_line_factor : 271-352', 'mths_since_earliest_cr_line_factor : 353-410', 'mths_since_earliest_cr_line_factor : 411-563', 'mths_since_earliest_cr_line_factor : >563', 'installment_factor', 'installment_factor : <183', 'installment_factor : 183-266', 'installment_factor : 267-517', 'installment_factor : 518-601', 'installment_factor : 602-880', 'installment_factor : 881-963', 'installment_factor : 964-1075', 'installment_factor : 1076-1242', 'installment_factor : >1242', 'delinq_2yrs : <4', 'delinq_2yrs : >=4', 'inq_last_6mths : 0-3', 'inq_last_6mths : 4-6', 'inq_last_6mths : >=6', 'open_acc_factor', 'open_acc_factor : 0', 'open_acc_factor : 1-3', 'open_acc_factor : 3-11', 'open_acc_factor : 12-25', 'open_acc_factor : 26-33', 'open_acc_factor : >34', 'pub_rec : 0-2', 'pub_rec : 3-4', 'pub_rec : 5-7', 'pub_rec : >7', 'total_acc_factor', 'total_acc_factor : <=27', 'total_acc_factor : 28-30', 'total_acc_factor : 30-45', 'total_acc_factor : 45-60', 'total_acc_factor : 60-72', 'total_acc_factor : >72', 'acc_now_delinq : 0', 'acc_now_delinq : 1-5', 'annual_inc_factor', 'annual_inc : <20k', 'annual_inc : 20k-30k', 'annual_inc : 30k-40k', 'annual_inc : 40k-50k', 'annual_inc : 50k-60k', 'annual_inc : 60k-70k', 'annual_inc : 70k-80k', 'annual_inc : 80k-90k', 'annual_inc : 90k-100k', 'annual_inc : 100k-120k', 'annual_inc : 120k-140k', 'annual_inc : >140k', 'mths_since_last_delinq : Missing', 'mths_since_last_delinq : 0-3', 'mths_since_last_delinq : 4-30', 'mths_since_last_delinq : 31-56', 'mths_since_last_delinq : >=57', 'dti_factor', 'dti : <=1.6', 'dti : 1.7-4.1', 'dti : 4.1-8.9', 'dti : 8.9-14.4', 'dti : 14.4-16.8', 'dti : 16.8-24', 'dti : 24-35.9', 'dti : >35.9', 'mths_since_last_record : Missing', 'mths_since_last_record : 0-2', 'mths_since_last_record : 3-20', 'mths_since_last_record : 21-40', 'mths_since_last_record : 41-65', 'mths_since_last_record : 66-84', 'mths_since_last_record : 85-96', 'mths_since_last_record : >=97']
]

# %%
# Here we store the names of the reference category dummy variables in a list.
ref_categories = [
    'Grade : G',  # Changed from 'grade:G'
    'home_ownership : RENT_OTHER_NONE_ANY',  # Changed from 'home_ownership:RENT_OTHER_NONE_ANY'
    'addr_state : ND_NE_IA_NV_FL_HI_AL',  # Changed from 'addr_state:ND_NE_IA_NV_FL_HI_AL'
    'verification_status : Verified',  # Changed from 'verification_status:Verified'
    'purpose : HO_OT_RE_ME',  # Changed from 'purpose:educ__sm_b__wedd__ren_en__mov__house'
    'initial_list_status : f',  # Changed from 'initial_list_status:f'
    'term : 60',  # Changed from 'term:60'
    'emp_length : 0',  # Changed from 'emp_length:0'
    'mths_since_issue_d_date_factor : >84',  # Changed from 'mths_since_issue_d:>84'
    'int_rate : >20.281',  # Changed from 'int_rate:>20.281'
    'mths_since_earliest_cr_line_factor : 141-270',  # Changed from 'mths_since_earliest_cr_line:<140'
    'delinq_2yrs : >=4',  # Changed from 'delinq_2yrs:>=4'
    'inq_last_6mths : >=6',  # Changed from 'inq_last_6mths:>6'
    'open_acc_factor : 0',  # Changed from 'open_acc:0'
    'pub_rec : 0-2',  # Changed from 'pub_rec:0-2'
    'total_acc_factor : <=27',  # Changed from 'total_acc:<=27'
    'acc_now_delinq : 0',  # Changed from 'acc_now_delinq:0'
    'annual_inc : <20k',  # Changed from 'annual_inc:<20K'
    'dti : >35.9',  # Changed from 'dti:>35'
    'mths_since_last_delinq : 0-3',  # Changed from 'mths_since_last_delinq:0-3'
    'mths_since_last_record : 0-2'  # Changed from 'mths_since_last_record:0-2'
]

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
# From the dataframe with input variables, we drop the variables with variable names in the list with reference categories. 
inputs_train.head()
# Out:
#         Grade : A  Grade : B  Grade : C  Grade : D  Grade : E  Grade : F  \
# 427211       True      False      False      False      False      False
# 206088      False      False       True      False      False      False
# 136020       True      False      False      False      False      False
# 412305      False      False      False       True      False      False
# 36159       False      False       True      False      False      False
#
#         sub_grade : A1  sub_grade : A2  sub_grade : A3  sub_grade : A4  ...  \
# 427211           False           False           False           False  ...
# 206088           False           False           False           False  ...
# 136020           False           False           False           False  ...
# 412305           False           False           False           False  ...
# 36159            False           False           False           False  ...
#
#         dti : 14.4-16.8  dti : 16.8-24  dti : 24-35.9  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
print(inputs_train.dtypes)
# Out:
# Grade : A                          bool
# Grade : B                          bool
# Grade : C                          bool
# Grade : D                          bool
# Grade : E                          bool
#                                   ...
# mths_since_last_record : 21-40    int64
# mths_since_last_record : 41-65    int64
# mths_since_last_record : 66-84    int64
# mths_since_last_record : 85-96    int64
# mths_since_last_record : >=97     int64
# Length: 225, dtype: object

# %%
print(inputs_train.select_dtypes(include=['object', 'category']).head())
# Out:
#        mths_since_issue_d_date_factor   int_rate_factor  funded_amnt_factor  \
# 427211         (1972800.0, 2051712.0]    (8.722, 9.135]  (23960.0, 24650.0]
# 206088         (2761920.0, 2840832.0]  (14.089, 14.502]   (9470.0, 10160.0]
# 136020         (2288448.0, 2367360.0]    (8.722, 9.135]  (19820.0, 20510.0]
# 412305         (1893888.0, 1972800.0]  (16.566, 16.978]  (17060.0, 17750.0]
# 36159          (4419072.0, 4497984.0]   (12.438, 12.85]    (8090.0, 8780.0]
#
#        mths_since_earliest_cr_line_factor  installment_factor open_acc_factor  \
# 427211           (15950764.8, 16465305.6]  (740.716, 768.603]  (18.48, 20.16]
# 206088           (10290816.0, 10805356.8]   (322.42, 350.307]  (13.44, 15.12]
# 136020           (13892601.6, 14407142.4]  (629.171, 657.057]    (8.4, 10.08]
# 412305            (9776275.2, 10290816.0]  (601.284, 629.171]    (8.4, 10.08]
# 36159             (9776275.2, 10290816.0]  (266.648, 294.534]  (13.44, 15.12]
#
# ...

# %%
inputs_train['mths_since_issue_d_date_factor'] = inputs_train['mths_since_issue_d_date_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['int_rate_factor'] = inputs_train['int_rate_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['funded_amnt_factor'] = inputs_train['funded_amnt_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['mths_since_earliest_cr_line_factor'] = inputs_train['mths_since_earliest_cr_line_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['installment_factor'] = inputs_train['installment_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)

inputs_train['open_acc_factor'] = inputs_train['open_acc_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['total_acc_factor'] = inputs_train['total_acc_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['annual_inc_factor'] = inputs_train['annual_inc_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)
inputs_train['dti_factor'] = inputs_train['dti_factor'].apply(lambda x: x.mid if hasattr(x, 'mid') else x)

# %%
inputs_train['mths_since_issue_d_date_factor'] = inputs_train['mths_since_issue_d_date_factor'].astype(str).factorize()[0]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse_output=False)
categorical_cols = ['mths_since_issue_d_date_factor', 'int_rate_factor', 'funded_amnt_factor', 
                    'mths_since_earliest_cr_line_factor', 'installment_factor', 
                    'open_acc_factor', 'total_acc_factor', 'annual_inc_factor', 
                    'dti_factor']

encoded_features = encoder.fit_transform(inputs_train[categorical_cols])
encoded_df = pd.DataFrame(encoded_features, columns=encoder.get_feature_names_out(categorical_cols))

# Drop original categorical columns and add encoded features
inputs_train = inputs_train.drop(columns=categorical_cols).reset_index(drop=True)
inputs_train = pd.concat([inputs_train, encoded_df], axis=1)

# %%
reg = LogisticRegression()

# %%
pd.options.display.max_rows = None

# %%
print(loan_data_targets_train.dtypes)
# Out:
# good_bad    object
# dtype: object

# %%
loan_data_targets_train = loan_data_targets_train.astype(int)

# %%
# Replace non-numeric values with a default value (e.g., 0 or 1)
loan_data_targets_train = loan_data_targets_train.replace({'invalid_value': 0})  # Replace 'invalid_value' with the actual problematic value
loan_data_targets_train = loan_data_targets_train.astype(int)

# %%
print(loan_data_targets_train.dtypes)
# Out:
# good_bad    int64
# dtype: object

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([0.53761228])

# %%
reg.coef_
# Displays the coefficients contained in the estimated ("fitted") object from the 'LogisticRegression' class.
# Out:
# array([[ 7.66895387e-02,  2.41546614e-02,  3.66600630e-02,
#          9.55672333e-02,  7.26716940e-02,  9.22080776e-02,
#         -9.26997604e-02,  2.14489306e-02,  4.60974780e-02,
#          7.85651434e-02,  2.32777471e-02,  1.36430282e-02,
#          3.96047736e-03,  1.90317152e-02, -2.52501567e-02,
#          1.27695973e-02,  2.37886005e-03, -2.41703180e-03,
#          5.79825907e-03, -4.73342507e-03,  3.56334007e-02,
#          1.32720943e-02,  8.41210472e-03,  7.00641815e-02,
#         -3.10245164e-02,  3.48433692e-02,  2.62996997e-02,
#         -2.68857722e-02, -2.35653483e-02,  1.15378833e-01,
#         -1.85557182e-02, -1.90709809e-02,  8.96114896e-02,
#          2.28516342e-02, -6.20435575e-02,  6.08594921e-02,
#          1.76272904e-01, -6.52507323e-02,  1.10793825e-01,
#         -5.32761063e-02, -3.66880194e-02, -1.47099109e-02,
#          1.61348071e-01,  2.57510048e-03,  6.38199436e-02,
#          1.49721354e-01,  1.67048581e-01,  3.90862372e-03,
# ...

# %%
feature_name = inputs_train.columns.values
# Stores the names of the columns of a dataframe in a variable.

summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
# Creates a dataframe with a column titled 'Feature name' and row values contained in the 'feature_name' variable.
summary_table['Coefficients'] = np.transpose(reg.coef_)
# Creates a new column in the dataframe, called 'Coefficients',
# with row values the transposed coefficients from the 'LogisticRegression' object.
summary_table.index = summary_table.index + 1
# Increases the index of every row of the dataframe with 1.
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
# Assigns values of the row with index 0 of the dataframe.
summary_table = summary_table.sort_index()
# Sorts the dataframe by index.
summary_table
# Out:
#                                           Feature name  Coefficients
# 0                                            Intercept      0.537612
# 1                                            Grade : A      0.076690
# 2                                            Grade : B      0.024155
# 3                                            Grade : C      0.036660
# 4                                            Grade : D      0.095567
# 5                                            Grade : E      0.072672
# 6                                            Grade : F      0.092208
# 7                                       sub_grade : A1     -0.092700
# 8                                       sub_grade : A2      0.021449
# 9                                       sub_grade : A3      0.046097
# 10                                      sub_grade : A4      0.078565
# 11                                      sub_grade : A5      0.023278
# 12                                      sub_grade : B1      0.013643
# ...

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):#,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)#,**args)

    def fit(self,X,y):
        self.model.fit(X,y)
        
        #### Get p-values for the fitted model ####
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X) ## Fisher Information Matrix
        Cramer_Rao = np.linalg.inv(F_ij) ## Inverse Information Matrix
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates # z-score for eaach model coefficient
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores] ### two tailed test for p-values
        
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        #self.z_scores = z_scores
        self.p_values = p_values
        #self.sigma_estimates = sigma_estimates
        #self.F_ij = F_ij

# %%
from sklearn import linear_model
import scipy.stats as stat

class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
reg = LogisticRegression_with_p_values()
# We create an instance of| an object from the newly created 'LogisticRegression_with_p_values()' class.

# %%
reg.fit(inputs_train, loan_data_targets_train)
# Estimates the coefficients of the object from the 'LogisticRegression' class
# with inputs (independent variables) contained in the first dataframe
# and targets (dependent variables) contained in the second dataframe.
# Out:
# C:\Users\lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Same as above.
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table

# %%
# This is a list.
p_values = reg.p_values
# We take the result of the newly added method 'p_values' and store it in a variable 'p_values'.
